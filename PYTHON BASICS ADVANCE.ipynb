# %% [markdown]
# <a href="https://colab.research.google.com/github/aman0556/PYTHON-BASICS-1-ASSIGNMENT/blob/main/PYTHON%20BASICS%20ADVANCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Q1- Write a code to reverse a string?
ANS1- Here are a few ways to reverse a string in Python:

# Method 1: Using Slicing

def reverse_string(s):
    return s[::-1]

# Test the function
print(reverse_string("Hello World"))  # Output: "dlroW olleH"


# Method 2: Using Reversed Function

def reverse_string(s):
    return "".join(reversed(s))

# Test the function
print(reverse_string("Hello World"))  # Output: "dlroW olleH"


# Method 3: Using Loop

def reverse_string(s):
    reversed_s = ""
    for char in s:
        reversed_s = char + reversed_s
    return reversed_s

# Test the function
print(reverse_string("Hello World"))  # Output: "dlroW olleH"


# Method 4: Using Recursion

def reverse_string(s):
    if len(s) == 0:
        return s
    else:
        return reverse_string(s[1:]) + s[0]

# Test the function
print(reverse_string("Hello World"))  # Output: "dlroW olleH"
Q2-Write a code to count the number of vowels in a string?
ANS2- Here are a few ways to count the number of vowels in a string in Python:

# Method 1: Using a For Loop

def count_vowels(s):
    vowels = "aeiouAEIOU"
    count = 0
    for char in s:
        if char in vowels:
            count += 1
    return count

# Test the function
print(count_vowels("Hello World"))  # Output: 3


# Method 2: Using List Comprehension

def count_vowels(s):
    vowels = "aeiouAEIOU"
    return sum(1 for char in s if char in vowels)

# Test the function
print(count_vowels("Hello World"))  # Output: 3


# Method 3: Using Regular Expressions

import re

def count_vowels(s):
    return len(re.findall("[aeiouAEIOU]", s))

# Test the function
print(count_vowels("Hello World"))  # Output: 3


# Method 4: Using Python's Built-in Functions

def count_vowels(s):
    vowels = "aeiouAEIOU"
    return sum(s.lower().count(vowel) for vowel in vowels)

# Test the function
print(count_vowels("Hello World"))  # Output: 3
Q3-Write a code to check if a given string is a palindrome or not?
ANS3- Here are a few ways to check if a given string is a palindrome or not in Python:

# Method 1: Using Slicing

def is_palindrome(s):
    return s == s[::-1]

# Test the function
print(is_palindrome("radar"))  # Output: True
print(is_palindrome("hello"))  # Output: False


# Method 2: Using Reversed Function

def is_palindrome(s):
    return s == "".join(reversed(s))

# Test the function
print(is_palindrome("radar"))  # Output: True
print(is_palindrome("hello"))  # Output: False


# Method 3: Using Loop

def is_palindrome(s):
    left = 0
    right = len(s) - 1
    while left < right:
        if s[left] != s[right]:
            return False
        left += 1
        right -= 1
    return True

# Test the function
print(is_palindrome("radar"))  # Output: True
print(is_palindrome("hello"))  # Output: False


# Method 4: Using Recursion

def is_palindrome(s):
    if len(s) <= 1:
        return True
    if s[0] != s[-1]:
        return False
    return is_palindrome(s[1:-1])

# Test the function
print(is_palindrome("radar"))  # Output: True
print(is_palindrome("hello"))  # Output: False
Q4-Write a code to check if two given strings are anagrams  of each other?
ANS4- Here are a few ways to check if two given strings are anagrams of each other in Python:

# Method 1: Using Sorted Function

def are_anagrams(str1, str2):
    return sorted(str1) == sorted(str2)

# Test the function
print(are_anagrams("listen", "silent"))  # Output: True
print(are_anagrams("hello", "world"))  # Output: False


# Method 2: Using Counter Class from Collections Module

from collections import Counter

def are_anagrams(str1, str2):
    return Counter(str1) == Counter(str2)

# Test the function
print(are_anagrams("listen", "silent"))  # Output: True
print(are_anagrams("hello", "world"))  # Output: False


# Method 3: Using Dictionary

def are_anagrams(str1, str2):
    dict1 = {}
    dict2 = {}

    for char in str1:
        if char in dict1:
            dict1[char] += 1
        else:
            dict1[char] = 1

    for char in str2:
        if char in dict2:
            dict2[char] += 1
        else:
            dict2[char] = 1

    return dict1 == dict2

# Test the function
print(are_anagrams("listen", "silent"))  # Output: True
print(are_anagrams("hello", "world"))  # Output: False


Note: These solutions are case-sensitive and do not ignore spaces or punctuation. If you want to ignore these, you can preprocess the strings to remove or transform them.
Q5-Write a code to find all occurrences of a given substring within another string?
ANS5- Here are a few ways to find all occurrences of a given substring within another string in Python:

# Method 1: Using str.find() Method

def find_substring(main_string, sub_string):
    occurrences = []
    index = main_string.find(sub_string)
    while index != -1:
        occurrences.append(index)
        index = main_string.find(sub_string, index + 1)
    return occurrences

# Test the function
main_string = "Hello, world. Hello again."
sub_string = "Hello"
print(find_substring(main_string, sub_string))  # Output: [0, 13]


# Method 2: Using str.index() Method

def find_substring(main_string, sub_string):
    occurrences = []
    try:
        index = main_string.index(sub_string)
        occurrences.append(index)
        while True:
            index = main_string.index(sub_string, index + 1)
            occurrences.append(index)
    except ValueError:
        pass
    return occurrences

# Test the function
main_string = "Hello, world. Hello again."
sub_string = "Hello"
print(find_substring(main_string, sub_string))  # Output: [0, 13]


# Method 3: Using Regular Expressions

import re

def find_substring(main_string, sub_string):
    return [m.start() for m in re.finditer(sub_string, main_string)]

# Test the function
main_string = "Hello, world. Hello again."
sub_string = "Hello"
print(find_substring(main_string, sub_string))  # Output: [0, 13]


# Method 4: Using Loop

def find_substring(main_string, sub_string):
    occurrences = []
    for i in range(len(main_string)):
        if main_string[i:i+len(sub_string)] == sub_string:
            occurrences.append(i)
    return occurrences

# Test the function
main_string = "Hello, world. Hello again."
sub_string = "Hello"
print(find_substring(main_string, sub_string))  # Output: [0, 13]
Q6-Write a code to perform basic string compression using the accounts of repeated characters?
ANS6- Here are a few ways to perform basic string compression using the accounts of repeated characters in Python:

# Method 1: Using Loop

def compress_string(s):
    if not s:
        return s

    compressed = []
    count = 1

    for i in range(1, len(s)):
        if s[i] == s[i-1]:
            count += 1
        else:
            compressed.append(s[i-1] + str(count))
            count = 1

    compressed.append(s[-1] + str(count))
    compressed_str = "".join(compressed)

    return compressed_str if len(compressed_str) < len(s) else s

# Test the function
print(compress_string("aabcccccaaa"))  # Output: "a2b1c5a3"
print(compress_string("abcdef"))  # Output: "abcdef"


# Method 2: Using itertools.groupby

import itertools

def compress_string(s):
    if not s:
        return s

    compressed = []
    for char, group in itertools.groupby(s):
        count = sum(1 for _ in group)
        compressed.append(char + str(count))

    compressed_str = "".join(compressed)

    return compressed_str if len(compressed_str) < len(s) else s

# Test the function
print(compress_string("aabcccccaaa"))  # Output: "a2b1c5a3"
print(compress_string("abcdef"))  # Output: "abcdef"


# Method 3: Using Regular Expressions

import re

def compress_string(s):
    if not s:
        return s

    compressed = re.sub(r'(.)\1*', lambda m: m.group(1) + str(len(m.group(0))), s)

    return compressed if len(compressed) < len(s) else s

# Test the function
print(compress_string("aabcccccaaa"))  # Output: "a2b1c5a3"
print(compress_string("abcdef"))  # Output: "abcdef"
Q7-write a code to determine if a string has all unique characters?
ANS7- Here are a few ways to determine if a string has all unique characters in Python:

# Method 1: Using Set

def has_unique_chars(s):
    return len(set(s)) == len(s)

# Test the function
print(has_unique_chars("abcdefg"))  # Output: True
print(has_unique_chars("abcadefg"))  # Output: False


# Method 2: Using Dictionary

def has_unique_chars(s):
    char_count = {}
    for char in s:
        if char in char_count:
            return False
        char_count[char] = 1
    return True

# Test the function
print(has_unique_chars("abcdefg"))  # Output: True
print(has_unique_chars("abcadefg"))  # Output: False


# Method 3: Using Python's Built-in Functions

def has_unique_chars(s):
    return len(s) == len(dict.fromkeys(s))

# Test the function
print(has_unique_chars("abcdefg"))  # Output: True
print(has_unique_chars("abcadefg"))  # Output: False


These codes will return True if the string has all unique characters and False otherwise.

Note: These solutions assume that the input string is case-sensitive and considers spaces and punctuation as characters. If you want to ignore case, spaces, or punctuation, you'll need to preprocess the string accordingly.
Q8-Write a code to convert a given string to uppercase or lowercase?
ANS8- Here are a few ways to convert a given string to uppercase or lowercase in Python:

# Uppercase Conversion
Method 1: Using upper() Method

def to_uppercase(s):
    return s.upper()

# Test the function
print(to_uppercase("Hello, World!"))  # Output: "HELLO, WORLD!"


Method 2: Using Python's Built-in Functions

def to_uppercase(s):
    return ''.join(chr(ord(c) - 32) if 'a' <= c <= 'z' else c for c in s)

# Test the function
print(to_uppercase("Hello, World!"))  # Output: "HELLO, WORLD!"


# Lowercase Conversion
Method 1: Using lower() Method

def to_lowercase(s):
    return s.lower()

# Test the function
print(to_lowercase("HELLO, WORLD!"))  # Output: "hello, world!"


Method 2: Using Python's Built-in Functions

def to_lowercase(s):
    return ''.join(chr(ord(c) + 32) if 'A' <= c <= 'Z' else c for c in s)

# Test the function
print(to_lowercase("HELLO, WORLD!"))  # Output: "hello, world!"


These codes will return the input string converted to uppercase or lowercase, respectively.
Q9-Write a code to count the number of words in a string?
ANS9- Here are a few ways to count the number of words in a string in Python:

# Method 1: Using split() Method

def count_words(s):
    return len(s.split())

# Test the function
print(count_words("Hello, World! This is a test."))  # Output: 7


# Method 2: Using Regular Expressions

import re

def count_words(s):
    return len(re.findall(r'\b\w+\b', s))

# Test the function
print(count_words("Hello, World! This is a test."))  # Output: 7


# Method 3: Using Loop

def count_words(s):
    count = 0
    in_word = False
    for char in s:
        if char.isspace():
            in_word = False
        elif not in_word:
            count += 1
            in_word = True
    return count

# Test the function
print(count_words("Hello, World! This is a test."))  # Output: 7


These codes will return the number of words in the input string.

Note:

- The split() method splits the string into words based on whitespace characters (spaces, tabs, newlines, etc.).
- The regular expression \b\w+\b matches word boundaries (\b) and word characters (\w+).
- The loop-based method iterates over the characters in the string, incrementing the word count when it encounters a non-space character after a space character.
Q10-Write a code to concatenate two strings without using the + operator?
ANS10- Here are a few ways to concatenate two strings without using the + operator in Python:

# Method 1: Using join() Method

def concat_strings(str1, str2):
    return "".join([str1, str2])

# Test the function
print(concat_strings("Hello, ", "World!"))  # Output: "Hello, World!"


# Method 2: Using format() Method

def concat_strings(str1, str2):
    return "{}{}".format(str1, str2)

# Test the function
print(concat_strings("Hello, ", "World!"))  # Output: "Hello, World!"


# Method 3: Using f-strings (Python 3.6+)

def concat_strings(str1, str2):
    return f"{str1}{str2}"

# Test the function
print(concat_strings("Hello, ", "World!"))  # Output: "Hello, World!"


# Method 4: Using % Operator

def concat_strings(str1, str2):
    return "%s%s" % (str1, str2)

# Test the function
print(concat_strings("Hello, ", "World!"))  # Output: "Hello, World!"


These codes will return the concatenation of the two input strings without using the + operator.
Q11-Write a code to remove all occurrences of a specific element from a list?
ANS11- Here are a few ways to remove all occurrences of a specific element from a list in Python:

# Method 1: Using list comprehension

def remove_element(lst, elem):
    return [x for x in lst if x != elem]

# Test the function
lst = [1, 2, 3, 2, 4, 2, 5]
elem = 2
print(remove_element(lst, elem))  # Output: [1, 3, 4, 5]


# Method 2: Using filter() function

def remove_element(lst, elem):
    return list(filter(lambda x: x != elem, lst))

# Test the function
lst = [1, 2, 3, 2, 4, 2, 5]
elem = 2
print(remove_element(lst, elem))  # Output: [1, 3, 4, 5]


# Method 3: Using while loop

def remove_element(lst, elem):
    while elem in lst:
        lst.remove(elem)
    return lst

# Test the function
lst = [1, 2, 3, 2, 4, 2, 5]
elem = 2
print(remove_element(lst, elem))  # Output: [1, 3, 4, 5]


# Method 4: Using list.remove() in a for loop

def remove_element(lst, elem):
    for _ in range(lst.count(elem)):
        lst.remove(elem)
    return lst

# Test the function
lst = [1, 2, 3, 2, 4, 2, 5]
elem = 2
print(remove_element(lst, elem))  # Output: [1, 3, 4, 5]


These codes will return the list with all occurrences of the specified element removed.
Q12- Implement a code to find the second largest number in a given list of integers?
ANS12- Here are a few ways to find the second largest number in a given list of integers in Python:

# Method 1: Using Sorting

def second_largest(nums):
    if len(nums) < 2:
        return None
    nums.sort()
    return nums[-2]

# Test the function
nums = [10, 20, 4, 45, 99]
print(second_largest(nums))  # Output: 45


# Method 2: Using Set and Sorting

def second_largest(nums):
    if len(set(nums)) < 2:
        return None
    return sorted(set(nums))[-2]

# Test the function
nums = [10, 20, 4, 45, 99]
print(second_largest(nums))  # Output: 45


# Method 3: Using max() and min() Functions

def second_largest(nums):
    if len(nums) < 2:
        return None
    max_num = second_max = float('-inf')
    for num in nums:
        if num > max_num:
            second_max = max_num
            max_num = num
        elif num > second_max and num != max_num:
            second_max = num
    if second_max == float('-inf'):
        return None
    return second_max

# Test the function
nums = [10, 20, 4, 45, 99]
print(second_largest(nums))  # Output: 45


# Method 4: Using heapq Module

import heapq

def second_largest(nums):
    if len(nums) < 2:
        return None
    return heapq.nlargest(2, nums)[-1]

# Test the function
nums = [10, 20, 4, 45, 99]
print(second_largest(nums))  # Output: 45


These codes will return the second largest number in the given list of integers. If the list has less than two unique elements, they will return None.
Q13- Create a code to count the occurrences of each element in a list and return a dictionary with element as key and their counts as values?
ANS13- Here are a few ways to count the occurrences of each element in a list and return a dictionary with element as key and their counts as values in Python:

# Method 1: Using Dictionary Comprehension

def count_elements(lst):
    return {i: lst.count(i) for i in set(lst)}

# Test the function
lst = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]
print(count_elements(lst))  # Output: {1: 1, 2: 2, 3: 3, 4: 4}


# Method 2: Using for Loop

def count_elements(lst):
    counts = {}
    for elem in lst:
        if elem in counts:
            counts[elem] += 1
        else:
            counts[elem] = 1
    return counts

# Test the function
lst = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]
print(count_elements(lst))  # Output: {1: 1, 2: 2, 3: 3, 4: 4}


# Method 3: Using collections.Counter

from collections import Counter

def count_elements(lst):
    return dict(Counter(lst))

# Test the function
lst = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]
print(count_elements(lst))  # Output: {1: 1, 2: 2, 3: 3, 4: 4}


These codes will return a dictionary where the keys are the unique elements from the list and the values are their respective counts.
Q14-Write a code to reverse a list in -place without using any built-in reverse functions?
ANS14- Here are a few ways to reverse a list in-place without using any built-in reverse functions in Python:

# Method 1: Using Two Pointers

def reverse_list_in_place(lst):
    left = 0
    right = len(lst) - 1
    while left < right:
        lst[left], lst[right] = lst[right], lst[left]
        left += 1
        right -= 1
    return lst

# Test the function
lst = [1, 2, 3, 4, 5]
print(reverse_list_in_place(lst))  # Output: [5, 4, 3, 2, 1]


# Method 2: Using Slicing

def reverse_list_in_place(lst):
    lst[:] = lst[::-1]
    return lst

# Test the function
lst = [1, 2, 3, 4, 5]
print(reverse_list_in_place(lst))  # Output: [5, 4, 3, 2, 1]


# Method 3: Using Recursion

def reverse_list_in_place(lst, start=0):
    if start >= len(lst) // 2:
        return lst
    lst[start], lst[-start - 1] = lst[-start - 1], lst[start]
    return reverse_list_in_place(lst, start + 1)

# Test the function
lst = [1, 2, 3, 4, 5]
print(reverse_list_in_place(lst))  # Output: [5, 4, 3, 2, 1]


These codes will reverse the input list in-place without using any built-in reverse functions.
Q15- Implement a code to find and remove duplicates from a least while preserving the original order of elements?
ANS15- Here are a few ways to find and remove duplicates from a list while preserving the original order of elements in Python:

# Method 1: Using List Comprehension and Index Method

def remove_duplicates(lst):
    return [x for i, x in enumerate(lst) if x not in lst[:i]]

# Test the function
lst = [1, 2, 3, 2, 4, 5, 6, 6, 7]
print(remove_duplicates(lst))  # Output: [1, 2, 3, 4, 5, 6, 7]


# Method 2: Using Dictionary

def remove_duplicates(lst):
    seen = {}
    return [x for x in lst if not (x in seen or seen.setdefault(x, 1))]

# Test the function
lst = [1, 2, 3, 2, 4, 5, 6, 6, 7]
print(remove_duplicates(lst))  # Output: [1, 2, 3, 4, 5, 6, 7]


# Method 3: Using OrderedDict

from collections import OrderedDict

def remove_duplicates(lst):
    return list(OrderedDict.fromkeys(lst))

# Test the function
lst = [1, 2, 3, 2, 4, 5, 6, 6, 7]
print(remove_duplicates(lst))  # Output: [1, 2, 3, 4, 5, 6, 7]


These codes will remove duplicates from the input list while preserving the original order of elements.
Q16- Create a code to check if a given list is sorted (either in ascending or descending order) or not ?
ANS16- Here are a few ways to check if a given list is sorted (either in ascending or descending order) or not in Python:

# Method 1: Using Comparison

def is_sorted(lst):
    return lst == sorted(lst) or lst == sorted(lst, reverse=True)

# Test the function
lst1 = [1, 2, 3, 4, 5]
lst2 = [5, 4, 3, 2, 1]
lst3 = [1, 3, 2, 4, 5]
print(is_sorted(lst1))  # Output: True
print(is_sorted(lst2))  # Output: True
print(is_sorted(lst3))  # Output: False


# Method 2: Using Iteration

def is_sorted(lst):
    is_ascending = is_descending = True
    for i in range(len(lst) - 1):
        if lst[i] > lst[i + 1]:
            is_ascending = False
        if lst[i] < lst[i + 1]:
            is_descending = False
    return is_ascending or is_descending

# Test the function
lst1 = [1, 2, 3, 4, 5]
lst2 = [5, 4, 3, 2, 1]
lst3 = [1, 3, 2, 4, 5]
print(is_sorted(lst1))  # Output: True
print(is_sorted(lst2))  # Output: True
print(is_sorted(lst3))  # Output: False


# Method 3: Using all() Function

def is_sorted(lst):
    return all(lst[i] <= lst[i + 1] for i in range(len(lst) - 1)) or all(lst[i] >= lst[i + 1] for i in range(len(lst) - 1))

# Test the function
lst1 = [1, 2, 3, 4, 5]
lst2 = [5, 4, 3, 2, 1]
lst3 = [1, 3, 2, 4, 5]
print(is_sorted(lst1))  # Output: True
print(is_sorted(lst2))  # Output: True
print(is_sorted(lst3))  # Output: False


These codes will check if the input list is sorted in either ascending or descending order and return True if it is, False otherwise.
Q17- Write a code to merge to sorted lists into a single sorted list?
ANS17- Here are a few ways to merge two sorted lists into a single sorted list in Python:

# Method 1: Using Built-in sort() Function

def merge_sorted_lists(list1, list2):
    return sorted(list1 + list2)

# Test the function
list1 = [1, 3, 5, 7]
list2 = [2, 4, 6, 8]
print(merge_sorted_lists(list1, list2))  # Output: [1, 2, 3, 4, 5, 6, 7, 8]


# Method 2: Using Two Pointers Technique

def merge_sorted_lists(list1, list2):
    result = []
    i = j = 0
    while i < len(list1) and j < len(list2):
        if list1[i] < list2[j]:
            result.append(list1[i])
            i += 1
        else:
            result.append(list2[j])
            j += 1
    result += list1[i:]
    result += list2[j:]
    return result

# Test the function
list1 = [1, 3, 5, 7]
list2 = [2, 4, 6, 8]
print(merge_sorted_lists(list1, list2))  # Output: [1, 2, 3, 4, 5, 6, 7, 8]


# Method 3: Using heapq.merge() Function

import heapq

def merge_sorted_lists(list1, list2):
    return list(heapq.merge(list1, list2))

# Test the function
list1 = [1, 3, 5, 7]
list2 = [2, 4, 6, 8]
print(merge_sorted_lists(list1, list2))  # Output: [1, 2, 3, 4, 5, 6, 7, 8]


These codes will merge two sorted lists into a single sorted list.
Q18- Implement a code to find the intersection of two given lists?
ANS18- Here are a few ways to find the intersection of two given lists in Python:

# Method 1: Using set intersection

def list_intersection(list1, list2):
    return list(set(list1) & set(list2))

# Test the function
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]
print(list_intersection(list1, list2))  # Output: [4, 5]


# Method 2: Using list comprehension

def list_intersection(list1, list2):
    return [value for value in list1 if value in list2]

# Test the function
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]
print(list_intersection(list1, list2))  # Output: [4, 5]


# Method 3: Using numpy intersect1d

import numpy as np

def list_intersection(list1, list2):
    return np.intersect1d(list1, list2).tolist()

# Test the function
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]
print(list_intersection(list1, list2))  # Output: [4, 5]


These codes will find the intersection of two given lists, i.e., the elements that are common to both lists.
Q19-Create a code to find the union of two lists without duplicates?
ANS19- Here are a few ways to find the union of two lists without duplicates in Python:

# Method 1: Using set union

def list_union(list1, list2):
    return list(set(list1) | set(list2))

# Test the function
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]
print(list_union(list1, list2))  # Output: [1, 2, 3, 4, 5, 6, 7, 8]


# Method 2: Using set union with sorted output

def list_union(list1, list2):
    return sorted(list(set(list1) | set(list2)))

# Test the function
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]
print(list_union(list1, list2))  # Output: [1, 2, 3, 4, 5, 6, 7, 8]


# Method 3: Using list comprehension

def list_union(list1, list2):
    return list(set([value for value in list1 + list2]))

# Test the function
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]
print(list_union(list1, list2))  # Output: [1, 2, 3, 4, 5, 6, 7, 8]


These codes will find the union of two lists without duplicates, i.e., all elements from both lists without any repetition.
Q20- Write a code to shuffle a given list randomly without using any built- in shuffle functions?
ANS20- Here are a few ways to shuffle a given list randomly without using any built-in shuffle functions in Python:

# Method 1: Using Random Index Swapping

import random

def shuffle_list(lst):
    for i in range(len(lst)):
        j = random.randint(0, len(lst) - 1)
        lst[i], lst[j] = lst[j], lst[i]
    return lst

# Test the function
lst = [1, 2, 3, 4, 5]
print(shuffle_list(lst))


# Method 2: Using Fisher-Yates Shuffle Algorithm

import random

def shuffle_list(lst):
    for i in range(len(lst) - 1, 0, -1):
        j = random.randint(0, i)
        lst[i], lst[j] = lst[j], lst[i]
    return lst

# Test the function
lst = [1, 2, 3, 4, 5]
print(shuffle_list(lst))


# Method 3: Using Random Permutation

import random

def shuffle_list(lst):
    indices = list(range(len(lst)))
    random.shuffle(indices)
    return [lst[i] for i in indices]

# Test the function
lst = [1, 2, 3, 4, 5]
print(shuffle_list(lst))


These codes will shuffle the input list randomly without using any built-in shuffle functions.

Note: While these methods can shuffle the list, they may not be as efficient or unbiased as the built-in shuffle functions.
Q21- Write a code that takes to tuples as input and returns a new tuple containing element that are common to both input tuples?
ANS21- Here are a few ways to write a code that takes two tuples as input and returns a new tuple containing elements that are common to both input tuples in Python:

# Method 1: Using set intersection

def common_elements(tuple1, tuple2):
    return tuple(set(tuple1) & set(tuple2))

# Test the function
tuple1 = (1, 2, 3, 4, 5)
tuple2 = (4, 5, 6, 7, 8)
print(common_elements(tuple1, tuple2))  # Output: (4, 5)


# Method 2: Using tuple comprehension

def common_elements(tuple1, tuple2):
    return tuple(i for i in tuple1 if i in tuple2)

# Test the function
tuple1 = (1, 2, 3, 4, 5)
tuple2 = (4, 5, 6, 7, 8)
print(common_elements(tuple1, tuple2))  # Output: (4, 5)


# Method 3: Using list comprehension and tuple conversion

def common_elements(tuple1, tuple2):
    return tuple([i for i in tuple1 if i in tuple2])

# Test the function
tuple1 = (1, 2, 3, 4, 5)
tuple2 = (4, 5, 6, 7, 8)
print(common_elements(tuple1, tuple2))  # Output: (4, 5)


These codes will return a new tuple containing elements that are common to both input tuples.
Q22-Create a code that prompts the user to enter two sets of integers separated by commas.then, print the intersection of this two sets?
ANS22- Here's a Python code that fulfills your requirements:


def get_set_from_user(prompt):
    user_input = input(prompt)
    try:
        return set(map(int, user_input.split(',')))
    except ValueError:
        print("Invalid input. Please enter integers separated by commas.")
        return get_set_from_user(prompt)

def main():
    set1 = get_set_from_user("Enter the first set of integers (separated by commas): ")
    set2 = get_set_from_user("Enter the second set of integers (separated by commas): ")

    intersection = set1 & set2
    print("Intersection of the two sets:", intersection)

if __name__ == "__main__":
    main()


Here's how this code works:

1. The get_set_from_user function prompts the user to enter a set of integers separated by commas. It attempts to convert the input into a set of integers. If the input is invalid (e.g., contains non-integer values), it displays an error message and recursively asks for input again.
2. The main function uses get_set_from_user to obtain two sets of integers from the user.
3. It calculates the intersection of the two sets using the & operator.
4. Finally, it prints the intersection of the two sets.

Example usage:


Enter the first set of integers (separated by commas): 1,2,3,4,5
Enter the second set of integers (separated by commas): 4,5,6,7,8
Intersection of the two sets: {4, 5}
Q23- Write a code to concatenate two tuples. The function should take to couples as input and return a new tuple containing element from both input tuples?
ANS23- Here are a few ways to concatenate two tuples in Python:

# Method 1: Using the + operator

def concat_tuples(tuple1, tuple2):
    return tuple1 + tuple2

# Test the function
tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)
print(concat_tuples(tuple1, tuple2))  # Output: (1, 2, 3, 4, 5, 6)


# Method 2: Using tuple unpacking

def concat_tuples(tuple1, tuple2):
    return (*tuple1, *tuple2)

# Test the function
tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)
print(concat_tuples(tuple1, tuple2))  # Output: (1, 2, 3, 4, 5, 6)


# Method 3: Using tuple conversion and concatenation

def concat_tuples(tuple1, tuple2):
    return tuple(list(tuple1) + list(tuple2))

# Test the function
tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)
print(concat_tuples(tuple1, tuple2))  # Output: (1, 2, 3, 4, 5, 6)


These codes will concatenate two input tuples and return a new tuple containing elements from both input tuples.
Q24- Develop a code that prompts the user to input two sets of strings. then,print the element that are present in the first set but not in the second set?
ANS24- Here's a Python code that fulfills your requirements:


def get_set_from_user(prompt):
    user_input = input(prompt)
    try:
        return set(user_input.split(','))
    except Exception as e:
        print(f"Invalid input. Error: {e}")
        return get_set_from_user(prompt)

def main():
    set1 = get_set_from_user("Enter the first set of strings (separated by commas): ")
    set2 = get_set_from_user("Enter the second set of strings (separated by commas): ")

    diff = set1 - set2
    print("Elements present in the first set but not in the second set:", diff)

if __name__ == "__main__":
    main()


Here's how this code works:

1. The get_set_from_user function prompts the user to enter a set of strings separated by commas. It attempts to convert the input into a set of strings. If the input is invalid, it displays an error message and recursively asks for input again.

2. The main function uses get_set_from_user to obtain two sets of strings from the user.

3. It calculates the difference between the two sets using the - operator, which returns a new set containing elements that are present in the first set but not in the second set.

4. Finally, it prints the resulting set.

Example usage:


Enter the first set of strings (separated by commas): apple,banana,cherry
Enter the second set of strings (separated by commas): banana,cherry,date
Elements present in the first set but not in the second set: {'apple'}
Q25- Create a code that takes a couple and two integers as input.The function should return a new tuple containing element from the original couple within the specified range of indices?
ANS25- Here's a Python code that fulfills your requirements:


def slice_tuple(tup, start, end):
    """
    Returns a new tuple containing elements from the original tuple
    within the specified range of indices.

    Args:
        tup (tuple): The input tuple.
        start (int): The starting index of the slice (inclusive).
        end (int): The ending index of the slice (exclusive).

    Returns:
        tuple: A new tuple containing the sliced elements.
    """
    if not isinstance(tup, tuple):
        raise TypeError("Input must be a tuple.")
    if not isinstance(start, int) or not isinstance(end, int):
        raise TypeError("Start and end indices must be integers.")
    if start < 0 or end > len(tup):
        raise ValueError("Invalid start or end index.")

    return tup[start:end]

# Example usage:
tup = (1, 2, 3, 4, 5, 6, 7, 8, 9)
start = 3
end = 7
print(slice_tuple(tup, start, end))  # Output: (4, 5, 6, 7)


This code defines a function slice_tuple that takes a tuple and two integers as input. It returns a new tuple containing elements from the original tuple within the specified range of indices.

The function includes error checking to ensure that the input is a tuple and the start and end indices are integers within the valid range. If any of these conditions are not met, the function raises an exception with a descriptive error message.
Q26-Write a code that prompts the user to input to sets of character. Then, print the union of this two sets?
ANS26- Here's a Python code that fulfills your requirements:


def get_set_from_user(prompt):
    user_input = input(prompt)
    try:
        return set(user_input)
    except Exception as e:
        print(f"Invalid input. Error: {e}")
        return get_set_from_user(prompt)

def main():
    set1 = get_set_from_user("Enter the first set of characters: ")
    set2 = get_set_from_user("Enter the second set of characters: ")

    union = set1.union(set2)
    print("Union of the two sets:", union)

if __name__ == "__main__":
    main()


Here's how this code works:

1. The get_set_from_user function prompts the user to enter a set of characters. It attempts to convert the input into a set of characters. If the input is invalid, it displays an error message and recursively asks for input again.

2. The main function uses get_set_from_user to obtain two sets of characters from the user.

3. It calculates the union of the two sets using the union method, which returns a new set containing all elements from both sets.

4. Finally, it prints the resulting set.

Example usage:


Enter the first set of characters: abc
Enter the second set of characters: cde
Union of the two sets: {'a', 'b', 'c', 'd', 'e'}
Q27-Develop a code that takes a tuple of integers as input. The function should return the maximum and minimum values from the tuple using tuple unpacking?
Ans27- Here's a Python code that fulfills your requirements:


def find_max_min(tup):
    """
    Returns the maximum and minimum values from the input tuple.

    Args:
        tup (tuple): A tuple of integers.

    Returns:
        tuple: A tuple containing the maximum and minimum values.
    """
    if not isinstance(tup, tuple):
        raise TypeError("Input must be a tuple.")
    if len(tup) == 0:
        raise ValueError("Input tuple cannot be empty.")
    if not all(isinstance(x, int) for x in tup):
        raise ValueError("Input tuple must contain only integers.")

    min_val, *_, max_val = tup
    for num in tup:
        if num < min_val:
            min_val = num
        elif num > max_val:
            max_val = num

    return max_val, min_val

# Example usage:
numbers = (12, 45, 7, 23, 56, 89, 34)
max_val, min_val = find_max_min(numbers)
print(f"Maximum value: {max_val}")
print(f"Minimum value: {min_val}")


This code defines a function find_max_min that takes a tuple of integers as input and returns the maximum and minimum values from the tuple.

Here's how it works:

1. The function first checks if the input is a tuple and if it's not empty. It also checks if all elements in the tuple are integers.
2. It then initializes min_val and max_val with the first element of the tuple.
3. The function iterates through the tuple, updating min_val and max_val whenever it finds a smaller or larger number, respectively.
4. Finally, it returns a tuple containing max_val and min_val.

Note that this implementation has a time complexity of O(n), where n is the number of elements in the tuple, because it makes a single pass through the tuple to find the minimum and maximum values.
Q28- Create a code that defines two sets of integers. Then, print the union,intersection,and difference of these two sets?
ANS28- Here's a Python code that fulfills your requirements:


def main():
    # Define two sets of integers
    set1 = {1, 2, 3, 4, 5}
    set2 = {4, 5, 6, 7, 8}

    # Print the sets
    print("Set 1:", set1)
    print("Set 2:", set2)

    # Calculate and print the union of the two sets
    union = set1.union(set2)
    print("Union:", union)

    # Calculate and print the intersection of the two sets
    intersection = set1.intersection(set2)
    print("Intersection:", intersection)

    # Calculate and print the difference of the two sets
    difference1 = set1.difference(set2)
    difference2 = set2.difference(set1)
    print("Difference (Set 1 - Set 2):", difference1)
    print("Difference (Set 2 - Set 1):", difference2)

if __name__ == "__main__":
    main()


Here's how this code works:

1. It defines two sets of integers, set1 and set2.
2. It prints the sets to the console.
3. It calculates the union of the two sets using the union method, which returns a new set containing all elements from both sets.
4. It calculates the intersection of the two sets using the intersection method, which returns a new set containing elements that are common to both sets.
5. It calculates the difference of the two sets using the difference method, which returns a new set containing elements that are present in the first set but not in the second set. It calculates the difference in both directions (Set 1 - Set 2 and Set 2 - Set 1).
6. Finally, it prints the results to the console.

Example Output:


Set 1: {1, 2, 3, 4, 5}
Set 2: {4, 5, 6, 7, 8}
Union: {1, 2, 3, 4, 5, 6, 7, 8}
Intersection: {4, 5}
Difference (Set 1 - Set 2): {1, 2, 3}
Difference (Set 2 - Set 1): {6, 7, 8}
Q29-Write a code that takes a tuple and an element as input. The function should return the count of occurrences of the given element in the tuple?
ANS29-Here's a Python code that fulfills your requirements:


def count_element(tup, elem):
    """
    Returns the count of occurrences of the given element in the tuple.

    Args:
        tup (tuple): The input tuple.
        elem: The element to be searched.

    Returns:
        int: The count of occurrences of the element.
    """
    if not isinstance(tup, tuple):
        raise TypeError("Input must be a tuple.")

    return tup.count(elem)

# Example usage:
numbers = (1, 2, 3, 4, 2, 5, 2, 6)
target = 2
count = count_element(numbers, target)
print(f"The element {target} occurs {count} times in the tuple.")


Here's how this code works:

1. The function count_element takes a tuple tup and an element elem as input.
2. It checks if the input is a tuple and raises a TypeError if not.
3. It uses the built-in count method of the tuple to count the occurrences of the given element.
4. Finally, it returns the count.

Example Output:


The element 2 occurs 3 times in the tuple.
Q30-Develop a code that prompts the user to input to sets of strings. Then, print the symmetric difference of this two sets?
ANS30- Here's a Python code that fulfills your requirements:


def get_set_from_user(prompt):
    user_input = input(prompt)
    try:
        return set(user_input.split(','))
    except Exception as e:
        print(f"Invalid input. Error: {e}")
        return get_set_from_user(prompt)

def main():
    # Prompt the user to input two sets of strings
    set1 = get_set_from_user("Enter the first set of strings (separated by commas): ")
    set2 = get_set_from_user("Enter the second set of strings (separated by commas): ")

    # Print the sets
    print("Set 1:", set1)
    print("Set 2:", set2)

    # Calculate and print the symmetric difference of the two sets
    symmetric_diff = set1.symmetric_difference(set2)
    print("Symmetric Difference:", symmetric_diff)

if __name__ == "__main__":
    main()


Here's how this code works:

1. The get_set_from_user function prompts the user to enter a set of strings separated by commas. It attempts to convert the input into a set of strings. If the input is invalid, it displays an error message and recursively asks for input again.

2. The main function uses get_set_from_user to obtain two sets of strings from the user.

3. It prints the sets to the console.

4. It calculates the symmetric difference of the two sets using the symmetric_difference method, which returns a new set containing elements that are in exactly one of the sets.

5. Finally, it prints the symmetric difference to the console.

Example Output:


Enter the first set of strings (separated by commas): apple,banana,cherry
Enter the second set of strings (separated by commas): banana,cherry,date
Set 1: {'apple', 'banana', 'cherry'}
Set 2: {'banana', 'cherry', 'date'}
Symmetric Difference: {'apple', 'date'}
Q31-Write a code that takes a list of words as input and returns a dictionary where the keys are unique words and the values are the frequencies of those words in the input list?
ANS31- Here's a Python code that fulfills your requirements:


def word_frequencies(word_list):
    """
    Returns a dictionary where the keys are unique words and the values are the frequencies of those words in the input list.

    Args:
        word_list (list): A list of words.

    Returns:
        dict: A dictionary containing word frequencies.
    """
    if not isinstance(word_list, list):
        raise TypeError("Input must be a list of words.")

    frequency_dict = {}
    for word in word_list:
        word = word.lower()  # Convert to lowercase for case-insensitive comparison
        if word in frequency_dict:
            frequency_dict[word] += 1
        else:
            frequency_dict[word] = 1

    return frequency_dict

# Example usage:
words = ["apple", "banana", "apple", "orange", "banana", "banana"]
frequencies = word_frequencies(words)
print(frequencies)


Here's how this code works:

1. The function word_frequencies takes a list of words as input.
2. It checks if the input is a list and raises a TypeError if not.
3. It initializes an empty dictionary frequency_dict to store word frequencies.
4. It iterates over each word in the input list, converts it to lowercase for case-insensitive comparison, and checks if the word is already in the dictionary.
5. If the word is already in the dictionary, it increments the word's frequency by 1. Otherwise, it adds the word to the dictionary with a frequency of 1.
6. Finally, it returns the dictionary containing word frequencies.

Example Output:


{'apple': 2, 'banana': 3, 'orange': 1}


Alternatively, you can use the collections.Counter class to achieve the same result with less code:


from collections import Counter

def word_frequencies(word_list):
    return Counter(word.lower() for word in word_list)
Q32- Write a code that takes to dictionaries as input and merges them into a single dictionary. If there are common keys, the value should be added together?
ANS32- Here's a Python code that fulfills your requirements:


def merge_dictionaries(dict1, dict2):
    """
    Merges two dictionaries into a single dictionary.
    If there are common keys, the values are added together.

    Args:
        dict1 (dict): The first dictionary.
        dict2 (dict): The second dictionary.

    Returns:
        dict: The merged dictionary.
    """
    if not isinstance(dict1, dict) or not isinstance(dict2, dict):
        raise TypeError("Both inputs must be dictionaries.")

    merged_dict = dict1.copy()
    for key, value in dict2.items():
        if key in merged_dict:
            merged_dict[key] += value
        else:
            merged_dict[key] = value

    return merged_dict

# Example usage:
dict1 = {"a": 10, "b": 20, "c": 30}
dict2 = {"b": 5, "c": 15, "d": 25}
merged_dict = merge_dictionaries(dict1, dict2)
print(merged_dict)


Here's how this code works:

1. The function merge_dictionaries takes two dictionaries as input.
2. It checks if both inputs are dictionaries and raises a TypeError if not.
3. It creates a copy of the first dictionary to avoid modifying the original dictionary.
4. It iterates over the key-value pairs in the second dictionary.
5. For each pair, it checks if the key already exists in the merged dictionary.
6. If the key exists, it adds the value from the second dictionary to the existing value in the merged dictionary.
7. If the key does not exist, it adds the key-value pair to the merged dictionary.
8. Finally, it returns the merged dictionary.

Example Output:


{'a': 10, 'b': 25, 'c': 45, 'd': 25}


Alternatively, you can use the collections.Counter class to achieve the same result with less code:


from collections import Counter

def merge_dictionaries(dict1, dict2):
    return dict(Counter(dict1) + Counter(dict2))
Q33- Write a code to access a value in a nested dictionary. The function should take the dictionary and a list of keys as input, and return the corresponding value. if any of the key do not exist in the dictionary,the functions should return none?
ANS33- Here's a Python code that fulfills your requirements:


def access_nested_dict(nested_dict, keys):
    """
    Accesses a value in a nested dictionary.

    Args:
        nested_dict (dict): The nested dictionary.
        keys (list): A list of keys to access the value.

    Returns:
        any: The corresponding value if all keys exist, otherwise None.
    """
    if not isinstance(nested_dict, dict) or not isinstance(keys, list):
        raise TypeError("Invalid input types.")

    current_dict = nested_dict
    for key in keys:
        if key in current_dict:
            current_dict = current_dict[key]
        else:
            return None

    return current_dict

# Example usage:
nested_dict = {
    "a": 1,
    "b": {
        "c": 2,
        "d": {
            "e": 3
        }
    }
}

keys1 = ["b", "c"]
keys2 = ["b", "d", "e"]
keys3 = ["x", "y"]  # Non-existent keys

print(access_nested_dict(nested_dict, keys1))  # Output: 2
print(access_nested_dict(nested_dict, keys2))  # Output: 3
print(access_nested_dict(nested_dict, keys3))  # Output: None


Here's how this code works:

1. The function access_nested_dict takes a nested dictionary and a list of keys as input.
2. It checks if the input types are correct and raises a TypeError if not.
3. It initializes a variable current_dict to the input dictionary.
4. It iterates over each key in the input list.
5. For each key, it checks if the key exists in the current dictionary.
6. If the key exists, it updates the current_dict to the value associated with the key.
7. If the key does not exist, it immediately returns None.
8. After iterating over all keys, it returns the final value in the current_dict.

This code handles nested dictionaries of arbitrary depth and returns None if any of the keys do not exist.
Q34- Write a code that takes a dictionary as input and returns a sorted version of it based on the values. You can choose whether to sort in ascending or descending order?
ANS34- Here's a Python code that fulfills your requirements:


def sort_dict_by_values(input_dict, ascending=True):
    """
    Returns a sorted version of the input dictionary based on the values.

    Args:
        input_dict (dict): The input dictionary.
        ascending (bool, optional): Whether to sort in ascending order. Defaults to True.

    Returns:
        dict: A sorted dictionary.
    """
    if not isinstance(input_dict, dict):
        raise TypeError("Input must be a dictionary.")

    sorted_dict = dict(sorted(input_dict.items(), key=lambda item: item[1], reverse=not ascending))
    return sorted_dict

# Example usage:
input_dict = {"apple": 5, "banana": 1, "cherry": 3, "date": 2, "elderberry": 4}
print("Original Dictionary:")
print(input_dict)

sorted_dict_ascending = sort_dict_by_values(input_dict)
print("\nSorted Dictionary (Ascending):")
print(sorted_dict_ascending)

sorted_dict_descending = sort_dict_by_values(input_dict, ascending=False)
print("\nSorted Dictionary (Descending):")
print(sorted_dict_descending)


Here's how this code works:

1. The function sort_dict_by_values takes a dictionary and an optional boolean flag ascending as input.
2. It checks if the input is a dictionary and raises a TypeError if not.
3. It uses the built-in sorted function to sort the dictionary items based on the values.
4. The key argument of the sorted function is set to a lambda function that returns the value of each item.
5. The reverse argument is set to the opposite of the ascending flag to control the sorting order.
6. The sorted items are then converted back to a dictionary using the dict constructor.
7. Finally, the function returns the sorted dictionary.

This code provides an efficient way to sort dictionaries by values in either ascending or descending order.
Q35- Write a code that inverts a dictionary, swapping keys and values Ensure that the inverted dictionary correctly handles cases where multiple keys have the same value by storing the key as a list in the inverted dictionary?
ANS35- Here's a Python code that fulfills your requirements:


def invert_dict(input_dict):
    """
    Inverts a dictionary, swapping keys and values.
    Handles cases where multiple keys have the same value by storing the key as a list in the inverted dictionary.

    Args:
        input_dict (dict): The input dictionary.

    Returns:
        dict: The inverted dictionary.
    """
    if not isinstance(input_dict, dict):
        raise TypeError("Input must be a dictionary.")

    inverted_dict = {}
    for key, value in input_dict.items():
        if value in inverted_dict:
            if isinstance(inverted_dict[value], list):
                inverted_dict[value].append(key)
            else:
                inverted_dict[value] = [inverted_dict[value], key]
        else:
            inverted_dict[value] = key

    return inverted_dict

# Example usage:
input_dict = {"a": 1, "b": 2, "c": 2, "d": 3, "e": 3, "f": 3}
print("Original Dictionary:")
print(input_dict)

inverted_dict = invert_dict(input_dict)
print("\nInverted Dictionary:")
print(inverted_dict)


Here's how this code works:

1. The function invert_dict takes a dictionary as input.
2. It checks if the input is a dictionary and raises a TypeError if not.
3. It initializes an empty dictionary inverted_dict to store the inverted key-value pairs.
4. It iterates over each key-value pair in the input dictionary.
5. For each pair, it checks if the value already exists in the inverted_dict.
6. If the value exists, it checks if the existing value is a list. If it's a list, it appends the current key to the list. If it's not a list, it converts the existing value to a list and appends the current key.
7. If the value does not exist, it adds the value as a key in the inverted_dict with the current key as its value.
8. Finally, the function returns the inverted_dict.

This code correctly handles cases where multiple keys have the same value by storing the keys as a list in the inverted dictionary.
